# %% [markdown]
# # Deep Learning Models
#
# A collection of deep learning models implemented on Pytorch for training purposes.
#
# Author: Lucas Martinuzzo Batista<br>
# GitHub: https://github.com/LucasMartinuzzo/Deep-Learning-Models

# %% [markdown]
# ## Multilayer Perceptron
#
# Implementation of a MLP with 2 hidden layers and batch normalization.

# %%
import torch 
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torch.utils.data import Dataset, DataLoader
from sklearn.datasets import make_blobs
import matplotlib.pylab as plt
from matplotlib.lines import Line2D
import numpy as np
import os
import time

# %%
device = "cpu"
if torch.cuda.is_available():
    print("Cuda is Available!")
    device = torch.device("cuda")
    torch.backends.cudnn.deterministic = True
# Out:
# Cuda is Available!

# %% [markdown]
# ### Dataset

# %%
TRAIN_BATCH_SIZE = 64
TEST_BATCH_SIZE = 1024

# %%
#transforms.ToTensor() normalizes the image from 0 - 255 to 0 - 1.
train_dataset = datasets.FashionMNIST(root="../../data/",
                                      train=True,
                                      download=True,
                                      transform=transforms.ToTensor())
test_dataset = datasets.FashionMNIST(root="../../data/",
                                      train=True,
                                      download=False,
                                      transform=transforms.ToTensor())

# %%
train_size = len(train_dataset)
test_size = len(test_dataset)

# %%
train_loader = DataLoader(train_dataset,batch_size=TRAIN_BATCH_SIZE,shuffle=True)
test_loader = DataLoader(test_dataset,batch_size=TEST_BATCH_SIZE)

# %%
figure = plt.figure(figsize=(10, 8))
cols, rows = 5, 5
for i in range(1, cols * rows + 1):
    sample_idx = torch.randint(len(train_dataset), size=(1,)).item()
    img, label = train_dataset[sample_idx]
    figure.add_subplot(rows, cols, i)
    plt.title(label)
    plt.axis("off")
    plt.imshow(img.squeeze(), cmap="gray")
plt.show()

# %% [markdown]
# ### Network

# %%
NUM_FEATURES = 28*28
DATASET_SIZE = len(test_dataset)
NUM_HIDDEN_1 = 64
NUM_HIDDEN_2 = 128
NUM_CLASSES = 10
RANDOM_SEED = 42

# %%
torch.manual_seed(RANDOM_SEED)

# %%
class MultilayerPerceptron(nn.Module):
  #Constructor
    def __init__(self,num_features,num_classes,num_hidden_1,num_hidden_2):
        super(MultilayerPerceptron,self).__init__()
        self.hidden1 = nn.Linear(num_features,num_hidden_1)
        self.bn1 = nn.BatchNorm1d(num_hidden_1)
        self.hidden2 = nn.Linear(num_hidden_1,num_hidden_2)
        self.bn2 = nn.BatchNorm1d(num_hidden_2)
        self.linear_out = nn.Linear(num_hidden_2,num_classes)
        
    
    def forward(self,x):
        out = self.hidden1(x)
        out = self.bn1(out)
        out = torch.relu(out)
        
        out = self.hidden2(out)
        out = self.bn2(out)
        out = torch.relu(out)
        
        out = self.linear_out(out)
        logits = torch.relu(out)
        probs = nn.functional.log_softmax(logits,dim=1)
        
        return logits, probs

# %%
model = MultilayerPerceptron(NUM_FEATURES,NUM_CLASSES,NUM_HIDDEN_1,NUM_HIDDEN_2)

# %%
model.to(device)
# Out:
# MultilayerPerceptron(
#   (hidden1): Linear(in_features=784, out_features=64, bias=True)
#   (bn1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (hidden2): Linear(in_features=64, out_features=128, bias=True)
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear_out): Linear(in_features=128, out_features=10, bias=True)
# )

# %%
optimizer = torch.optim.SGD(model.parameters(),lr=0.05)
loss_criterion = nn.CrossEntropyLoss()

# %%
def train(model,optimizer,loss_function,train_loader,test_loader,epochs,train_size,test_size):
    LOSSES = []
    ACCURACIES = []
    start_time = time.time()
    model.train()
    for epoch in range(epochs):
        accumulated_loss = 0
        correct = 0
        for x, y in train_loader:
            x = x.view(-1,NUM_FEATURES).to(device)
            y = y.to(device)
            optimizer.zero_grad()
            logits,probs = model(x)
            loss = loss_function(logits,y)
            loss.backward()
            optimizer.step()
            accumulated_loss += loss.item()
            y_hat = probs.argmax(dim=1)
            correct += (y_hat  == y).sum().item()
        LOSSES.append(accumulated_loss)
        train_accuracy = correct/train_size
        model.eval()
        correct = 0
        for x_test,y_test in test_loader:
            x_test = x_test.view(-1,NUM_FEATURES).to(device)
            y_test = y_test.to(device)
            logits,probs = model(x_test)
            y_hat = probs.argmax(dim=1)
            correct += (y_hat  == y_test).sum().item()
        test_accuracy = correct/test_size
        print("Epoch {}/{}. Cost: {}. Train Accuracy: {}. Test Accuracy: {}".format(
                epoch+1,epochs,accumulated_loss,train_accuracy,test_accuracy))
        print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))
        ACCURACIES.append(test_accuracy)
    print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
    return LOSSES,ACCURACIES

# %%
LOSS, ACC = train(model,optimizer,loss_criterion,train_loader,test_loader,
                  epochs=20,train_size=train_size,test_size=test_size)
# Out:
# Epoch 1/20. Cost: 470.69516602158546. Train Accuracy: 0.82895. Test Accuracy: 0.8433666666666667
# Time elapsed: 0.24 min
# Epoch 2/20. Cost: 413.7048797160387. Train Accuracy: 0.8395333333333334. Test Accuracy: 0.8651
# Time elapsed: 0.44 min
# Epoch 3/20. Cost: 336.5183885768056. Train Accuracy: 0.8670833333333333. Test Accuracy: 0.8797166666666667
# Time elapsed: 0.65 min
# Epoch 4/20. Cost: 311.3969521224499. Train Accuracy: 0.8772. Test Accuracy: 0.8754833333333333
# Time elapsed: 0.85 min
# Epoch 5/20. Cost: 294.5626872032881. Train Accuracy: 0.8837333333333334. Test Accuracy: 0.8931166666666667
# Time elapsed: 1.06 min
# Epoch 6/20. Cost: 280.9315335303545. Train Accuracy: 0.88745. Test Accuracy: 0.8779666666666667
# Time elapsed: 1.27 min
# Epoch 7/20. Cost: 272.3773413076997. Train Accuracy: 0.8919333333333334. Test Accuracy: 0.8874
# Time elapsed: 1.47 min
# Epoch 8/20. Cost: 261.08187629282475. Train Accuracy: 0.895. Test Accuracy: 0.9085333333333333
# Time elapsed: 1.68 min
# Epoch 9/20. Cost: 253.0303491204977. Train Accuracy: 0.8994833333333333. Test Accuracy: 0.8928
# Time elapsed: 1.88 min
# Epoch 10/20. Cost: 248.08601417392492. Train Accuracy: 0.90075. Test Accuracy: 0.9002666666666667
# Time elapsed: 2.09 min
# Epoch 11/20. Cost: 238.54345770180225. Train Accuracy: 0.90485. Test Accuracy: 0.9064166666666666
# Time elapsed: 2.30 min
# Epoch 12/20. Cost: 232.54614452645183. Train Accuracy: 0.9065333333333333. Test Accuracy: 0.9032
# Time elapsed: 2.51 min
# Epoch 13/20. Cost: 228.32404325157404. Train Accuracy: 0.9076833333333333. Test Accuracy: 0.9143666666666667
# Time elapsed: 2.72 min
# Epoch 14/20. Cost: 222.78503692895174. Train Accuracy: 0.9104666666666666. Test Accuracy: 0.9105333333333333
# Time elapsed: 2.95 min
# Epoch 15/20. Cost: 216.10356088727713. Train Accuracy: 0.91435. Test Accuracy: 0.9137333333333333
# Time elapsed: 3.15 min
# Epoch 16/20. Cost: 212.40438655391335. Train Accuracy: 0.9139666666666667. Test Accuracy: 0.9158
# Time elapsed: 3.34 min
# Epoch 17/20. Cost: 206.53980350866914. Train Accuracy: 0.9159333333333334. Test Accuracy: 0.9166666666666666
# Time elapsed: 3.53 min
# Epoch 18/20. Cost: 204.60486179590225. Train Accuracy: 0.9170833333333334. Test Accuracy: 0.9254
# Time elapsed: 3.72 min
# Epoch 19/20. Cost: 199.23978252708912. Train Accuracy: 0.9183666666666667. Test Accuracy: 0.9246833333333333
# Time elapsed: 3.91 min
# Epoch 20/20. Cost: 194.65043499320745. Train Accuracy: 0.9210833333333334. Test Accuracy: 0.9253333333333333
# Time elapsed: 4.12 min
# Total Training Time: 4.12 min

# %%
# Plot the loss and accuracy

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.plot(LOSS, color=color)
ax1.set_xlabel('epoch', color=color)
ax1.set_ylabel('Cost', color=color)
ax1.tick_params(axis='y', color=color)
    
ax2 = ax1.twinx()  
color = 'tab:blue'
ax2.set_ylabel('accuracy', color=color) 
ax2.set_xlabel('epoch', color=color)
ax2.plot( ACC, color=color)
ax2.tick_params(axis='y', color=color)
fig.tight_layout()
